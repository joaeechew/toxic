# %% [markdown]
# Use a RF to stack LSTM predictions with engineered features

# %%
import os
import logging

# %%
dir_path = os.path.realpath('..')

# %% [markdown]
# ## Import data

# %%
import numpy as np
import pandas as pd

# %%
path = 'data/processed/stacking.csv'

full_path = os.path.join(dir_path, path)
df = pd.read_csv(full_path, header=0, index_col=0)
print("Dataset has {} rows, {} columns.".format(*df.shape))
# Out:
# Dataset has 19171 rows, 13 columns.

# %%
# fill NaN with string "unknown"
df.fillna('unknown',inplace=True)

# %% [markdown]
# ## Feature engineering

# %%
df['processed'] = df['comment_text'].str.split()
df['uppercase_count'] = df['processed'].apply(lambda x: sum(1 for t in x if t.isupper() and len(t)>2))
df = df.drop(['processed'], axis=1)

# %%
df.head()
# Out:
#               toxic  severe_toxic  obscene  threat  insult  identity_hate  \
# id
# 343671421527      0             0        0       0       0              0
# 484437552026      0             0        0       0       0              0
# 818275822896      0             0        0       0       0              0
# 788660525714      0             0        0       0       0              0
# 398705378355      0             0        0       0       0              0
#
#                                                    comment_text  toxic_pred  \
# id
# 343671421527  I can possibly see this information being adde...    0.000365
# 484437552026  Grandmaster take a look at your own source at ...    0.005549
# 818275822896  I just added details to show the actual scope ...    0.000923
# 788660525714  "\n\nHi. I am offended by your use of the word...    0.013041
# 398705378355  What is unacceptable, and deserves an apology ...    0.001005
#
#               severe_toxic_pred  obscene_pred  threat_pred  insult_pred  \
# id
# 343671421527           0.000001      0.000278     0.000002     0.000053
# 484437552026           0.000045      0.002324     0.000060     0.002056
# 818275822896           0.000004      0.000714     0.000007     0.000228
# 788660525714           0.000045      0.004630     0.000067     0.003697
# 398705378355           0.000002      0.000333     0.000003     0.000100
#
#               identity_hate_pred  uppercase_count
# id
# 343671421527            0.000004                0
# 484437552026            0.000581                0
# 818275822896            0.000039                3
# 788660525714            0.000210                1
# 398705378355            0.000006                0

# %%
from sklearn.model_selection import train_test_split

seed = 42
np.random.seed(seed)
test_size = 0.2
target = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
corpus = 'comment_text'

X = df.drop(target + [corpus], axis=1)
y = df[target]


Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=test_size, random_state=seed)

# %%
X.head()
# Out:
#               toxic_pred  severe_toxic_pred  obscene_pred  threat_pred  \
# id
# 343671421527    0.000365           0.000001      0.000278     0.000002
# 484437552026    0.005549           0.000045      0.002324     0.000060
# 818275822896    0.000923           0.000004      0.000714     0.000007
# 788660525714    0.013041           0.000045      0.004630     0.000067
# 398705378355    0.001005           0.000002      0.000333     0.000003
#
#               insult_pred  identity_hate_pred  uppercase_count
# id
# 343671421527     0.000053            0.000004                0
# 484437552026     0.002056            0.000581                0
# 818275822896     0.000228            0.000039                3
# 788660525714     0.003697            0.000210                1
# 398705378355     0.000100            0.000006                0

# %% [markdown]
# ## Model fit

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics
# 29805967828   0.000000  0.000369  0.000005  0.000173  0.000000
# 134687700701  0.000000  0.043723  0.000518  0.045195  0.000095
# 335640223467  0.000000  0.000460  0.000005  0.000187  0.000000
# 24917306209   0.000000  0.000394  0.000004  0.000172  0.000000
# 21107937190   0.000000  0.000589  0.000006  0.000250  0.000000
# 344915488915  0.000000  0.004188  0.001130  0.013031  0.000793
# 510580404538  0.000000  0.000252  0.000004  0.000138  0.000000
# 987402184675  0.000000  0.000583  0.000006  0.000250  0.000000
# 230943290970  0.000000  0.000240  0.000004  0.000143  0.000000
# 972188672842  0.000000  0.000233  0.000004  0.000145  0.000000
# ...                ...       ...       ...       ...       ...
# 564762112378  0.293912  0.965215  0.053118  0.841595  0.083223
# 514781803898  0.000000  0.003090  0.000841  0.002932  0.000000
# 693117859311  0.000000  0.000301  0.000004  0.000161  0.000000
# 509577456933  0.002011  0.031237  0.002959  0.084732  0.013545
# 284630845656  0.000000  0.000233  0.000004  0.000135  0.000000
# 730171929323  0.081629  0.674938  0.027499  0.679572  0.098418
# 44177296493   0.000000  0.003155  0.000773  0.002749  0.000000
# 160903771568  0.000000  0.000318  0.000004  0.000171  0.000000
# 920416636840  0.000000  0.000232  0.000004  0.000147  0.000000
# 397182480458  0.000000  0.002474  0.000252  0.002226  0.000000
# 748709063967  0.000000  0.000736  0.000017  0.000389  0.000000
# 86915358450   0.000000  0.012898  0.000623  0.016222  0.006905
# 543795275789  0.000000  0.002586  0.000366  0.001926  0.000000
# 79844377320   0.000000  0.000233  0.000004  0.000145  0.000000
# 292297649944  0.000000  0.003034  0.000831  0.002959  0.000000
# 352146108493  0.000000  0.000539  0.000005  0.000242  0.000000
# 563488907817  0.576247  0.999322  0.005358  0.958164  0.073190
# 713861767319  0.000000  0.024550  0.000551  0.041539  0.034716
# 255230945134  0.000000  0.000233  0.000004  0.000135  0.000000
# 233492140433  0.000000  0.000346  0.000004  0.000146  0.000000
# 775112880922  0.000000  0.000650  0.000011  0.000303  0.000000
# 845120351544  0.000000  0.000233  0.000004  0.000135  0.000000
# 529641534745  0.000000  0.002214  0.000306  0.001550  0.000000
# 682395724874  0.000000  0.001300  0.000124  0.001631  0.000000
# 781538585771  0.000000  0.000340  0.000004  0.000163  0.000000
# 293582637871  0.000000  0.000320  0.000004  0.000164  0.000000
# 931724309325  0.000000  0.000429  0.000004  0.000174  0.000000
# 466660538620  0.000000  0.000233  0.000004  0.000135  0.000000
# 136157091280  0.000039  0.010413  0.001171  0.020516  0.020097
# 790717763531  0.000000  0.004790  0.000884  0.009859  0.001090
#
# [3835 rows x 12 columns]

# %%
# concatenating features with lstm preds
y_pred = clf_cv.predict_proba(Xtest)
hold_out_preds = pd.DataFrame(index=ytest.index, columns=target)
i = 0
for label in target:
    hold_out_preds[label] = y_pred[i][:,1]
    i += 1
losses = []

for label in target:
    loss = log_loss(ytest[label], hold_out_preds[label])
    losses.append(loss)
    print("{} log loss is {} .".format(label, loss))
    
print("Combined log loss: {} .".format(np.mean(losses)))
# Out:
# toxic log loss is 0.09787929010850749 .
# severe_toxic log loss is 0.026725898185510445 .
# obscene log loss is 0.05470538602085354 .
# threat log loss is 0.010094469485710533 .
# insult log loss is 0.06404614090386715 .
# identity_hate log loss is 0.032323306720357 .
# Combined log loss: 0.04762908190413436 .

# %%
# Comparing to original preds
for label in target:
    loss = log_loss(ytest[label], Xtest[label+'_pred'])
    losses.append(loss)
    print("{} log loss is {} .".format(label, loss))
    
print("Combined log loss: {} .".format(np.mean(losses)))
# Out:
# toxic log loss is 0.09974531484030262 .
# severe_toxic log loss is 0.02043052522355615 .
# obscene log loss is 0.05536954658653976 .
# threat log loss is 0.010520945531656771 .
# insult log loss is 0.06303551417441342 .
# identity_hate log loss is 0.02521755794712749 .
# Combined log loss: 0.046356294446222135 .

# %%
clf_cv.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 8,
#  'min_samples_split': 8,
#  'n_estimators': 200}

# %% [markdown]
# ## Rf only

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import log_loss

# %%
#Tuning the model
param_grid = { "n_estimators"      : [150, 200, 250],
           "max_depth"         : [4, 8],
           "min_samples_split" : [4, 8] ,
           "bootstrap": [True]}

# %%
# %%time
clf = RandomForestClassifier(random_state=seed)

clf_cv = GridSearchCV(clf, param_grid, cv=5)
clf_cv.fit(Xtrain['uppercase_count'].reshape(-1,1), ytrain)
# Out:
# //anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:4: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
# CPU times: user 2min 23s, sys: 1.04 s, total: 2min 24s
# Wall time: 2min 25s

# %%
# features only
y_pred = clf_cv.predict_proba(Xtest['uppercase_count'].reshape(-1,1))
hold_out_preds = pd.DataFrame(index=ytest.index, columns=target)
i = 0
for label in target:
    hold_out_preds[label] = y_pred[i][:,1]
    i += 1
losses = []

for label in target:
    loss = log_loss(ytest[label], hold_out_preds[label])
    losses.append(loss)
    print("{} log loss is {} .".format(label, loss))
    
print("Combined log loss: {} .".format(np.mean(losses)))
# Out:
# //anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   if __name__ == '__main__':
# toxic log loss is 0.30907860864538406 .
# severe_toxic log loss is 0.039100500903573615 .
# obscene log loss is 0.20099846187848056 .
# threat log loss is 0.016168582699123156 .
# insult log loss is 0.19658491496102598 .
# identity_hate log loss is 0.04781023162879908 .
# Combined log loss: 0.13495688345273107 .

# %%
hold_out_preds
# Out:
#                  toxic  severe_toxic   obscene    threat    insult  \
# id
# 771050023016  0.093615      0.009622  0.052160  0.002611  0.051097
# 752085470079  0.076465      0.012159  0.046952  0.002283  0.039784
# 260894087160  0.076465      0.012159  0.046952  0.002283  0.039784
# 608267384331  0.093615      0.009622  0.052160  0.002611  0.051097
# 743416916956  0.093615      0.009622  0.052160  0.002611  0.051097
# 159004111621  0.093615      0.009622  0.052160  0.002611  0.051097
# 576654454044  0.093615      0.009622  0.052160  0.002611  0.051097
# 900304929759  0.093615      0.009622  0.052160  0.002611  0.051097
# 830539624013  0.093615      0.009622  0.052160  0.002611  0.051097
# 819090374692  0.093615      0.009622  0.052160  0.002611  0.051097
# 293582637871  0.093615      0.009622  0.052160  0.002611  0.051097
# 931724309325  0.093615      0.009622  0.052160  0.002611  0.051097
# 466660538620  0.093615      0.009622  0.052160  0.002611  0.051097
# 136157091280  0.093615      0.009622  0.052160  0.002611  0.051097
# 790717763531  0.093615      0.009622  0.052160  0.002611  0.051097
#
#               identity_hate
# id
# 771050023016       0.007506
# 752085470079       0.004249
# 260894087160       0.004249
# 608267384331       0.007506
# 743416916956       0.007506
# 159004111621       0.007506
# 576654454044       0.007506
# 900304929759       0.007506
# 830539624013       0.007506
# 819090374692       0.007506
# 515170494172       0.007506
# 969961710412       0.007506
# 313047977385       0.007506
# 306475186335       0.023226
# 697758035288       0.007506
# 866217911053       0.007506
# 753699974283       0.040753
# 33883921197        0.007506
# 206384547954       0.007506
# 870983429218       0.137234
# 29805967828        0.007506
# 134687700701       0.007506
# 335640223467       0.007506
# 24917306209        0.003093
# 21107937190        0.007506
# 344915488915       0.007506
# 510580404538       0.007506
# 987402184675       0.007506
# 230943290970       0.004249
# 972188672842       0.007506
# ...                     ...
# 564762112378       0.048528
# 514781803898       0.007506
# 693117859311       0.007506
# 509577456933       0.003093
# 284630845656       0.007506
# 730171929323       0.007506
# 44177296493        0.004249
# 160903771568       0.003093
# 920416636840       0.003093
# 397182480458       0.007506
# 748709063967       0.007506
# 86915358450        0.004249
# 543795275789       0.007506
# 79844377320        0.007506
# 292297649944       0.007506
# 352146108493       0.007506
# 563488907817       0.007506
# 713861767319       0.007506
# 255230945134       0.007506
# 233492140433       0.004249
# 775112880922       0.007506
# 845120351544       0.007506
# 529641534745       0.007506
# 682395724874       0.007506
# 781538585771       0.004249
# 293582637871       0.007506
# 931724309325       0.007506
# 466660538620       0.007506
# 136157091280       0.007506
# 790717763531       0.007506
#
# [3835 rows x 6 columns]

# %%
ytest.describe()
# Out:
#              toxic  severe_toxic      obscene       threat       insult  \
# count  3835.000000   3835.000000  3835.000000  3835.000000  3835.000000
# mean      0.098566      0.007301     0.051890     0.002347     0.050587
# std       0.298117      0.085146     0.221835     0.048393     0.219181
# min       0.000000      0.000000     0.000000     0.000000     0.000000
# 25%       0.000000      0.000000     0.000000     0.000000     0.000000
# 50%       0.000000      0.000000     0.000000     0.000000     0.000000
# 75%       0.000000      0.000000     0.000000     0.000000     0.000000
# max       1.000000      1.000000     1.000000     1.000000     1.000000
#
#        identity_hate
# count    3835.000000
# mean        0.008344
# std         0.090977
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
# Comparing to original preds
for label in target:
    loss = log_loss(ytest[label], Xtest[label+'_pred'])
    losses.append(loss)
    print("{} log loss is {} .".format(label, loss))
    
print("Combined log loss: {} .".format(np.mean(losses)))
# Out:
# toxic log loss is 0.09974531484030262 .
# severe_toxic log loss is 0.02043052522355615 .
# obscene log loss is 0.05536954658653976 .
# threat log loss is 0.010520945531656771 .
# insult log loss is 0.06303551417441342 .
# identity_hate log loss is 0.02521755794712749 .
# Combined log loss: 0.046356294446222135 .

# %%
clf_cv.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 8,
#  'min_samples_split': 8,
#  'n_estimators': 200}
