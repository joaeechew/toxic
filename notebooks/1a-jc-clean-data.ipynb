# %%
import os
import pandas as pd

# %%
dir_path = os.path.realpath('..')

# %%
path = 'data/raw/train.csv'

full_path = os.path.join(dir_path, path)
df_train = pd.read_csv(full_path, header=0, index_col=0)
print("Dataset has {} rows, {} columns.".format(*df_train.shape))
# Out:
# Dataset has 95851 rows, 7 columns.

# %%
path = 'data/raw/test.csv'

full_path = os.path.join(dir_path, path)
df_test = pd.read_csv(full_path, header=0, index_col=0)
print("Dataset has {} rows, {} columns.".format(*df_test.shape))
# Out:
# Dataset has 226998 rows, 1 columns.

# %% [markdown]
# ## Data cleaning

# %%
# fill NaN with string "unknown"
df_train.fillna('unknown',inplace=True)
df_test.fillna('unknown',inplace=True)

# %% [markdown]
# ## Clean text

# %%
import string
import nltk
nltk.data.path.append("/Users/joaeechew/dev/nltk_data")

from nltk import word_tokenize
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from gensim.corpora.dictionary import Dictionary

# %%
print(df.comment_text[:10])
# Out:
# id
# 22256635     Nonsense?  kiss off, geek. what I said is true...
# 27450690     "\n\n Please do not vandalize pages, as you di...
# 54037174     "\n\n ""Points of interest"" \n\nI removed the...
# 77493077     Asking some his nationality is a Racial offenc...
# 79357270     The reader here is not going by my say so for ...
# 82428052         Fried chickens \n\nIs dat sum fried chickens?
# 87311443     Why can you put English for example on some pl...
# 114749757    Guy Fawkes \n\nim a resident in bridgwater and...
# 138560519    as far as nicknames go this article is embarra...
# 139353149    Woodland Meadows\nGood to hear that you correc...
# Name: comment_text, dtype: object

# %%
df.comment_text.iloc[10234]
# Out:
# "Response to the lies in your RFC TAB \n\nSo what happens when all of your and  wikitricks and threats fail? Then what? Are you going to be willing to engage in reasonable discussion?\n\nDo you want to discuss this reasonably or merely continue to engage in this sily pantomime?\n\nYou are wrong about Canaen. I have nothing to do with him. Your personal attack on him is based on lies. Out of decency, you should remove them. And if you are not going to be decent, how will we progress?\n\n Vegan smegma \n\n male penis]]\n\nOn a more productive note, and frankly, I produce tons of the stuff, I would like to discuss with you the vegan aspects of smegma and whether or not you might consider it suitable for your inclusion. \n\nIf you are not sure what that means, there is a very good article on the subject here ; , although perhaps we ought consider starting a separate page on vegan smegma and other cruelty free animal products that may be considered by some vegan.\n\nFrom the vegan point of view, it is almost unique, along with sperm, mother's milk and placentas, as being an entirely cruelty free animal product. A rich source of proteins and, indeed, a live food. \n\nSince you are so interested in the fullness and accuracy of vegan minutae, we would be happy to discuss your interest in this and offer you a chance to digest our point of view or contribute."

# %% [markdown]
# First start with simpler models (more cleaning).
#
# I want to:
# - Keep exclamation marks only as it may be an indicator for toxicity
# - Keep uppercase as it might be toxic
# - Remove stopwords (to try with and without)
# - Stemming (to try with and without)
# - Remove numbers

# %%
def preprocess_text(corpus):
    """Takes a corpus in list format and applies basic preprocessing steps of word tokenization,
     removing of english stop words, and lemmatization."""
    processed_corpus = []
    english_words = set(nltk.corpus.words.words())
    english_stopwords = set(stopwords.words('english'))
    wordnet_lemmatizer = WordNetLemmatizer()
    tokenizer = RegexpTokenizer(r'[\w|!]+')
    for row in corpus:
        word_tokens = tokenizer.tokenize(row)
        word_tokens_no_digits = [t for t in word_tokens if not t.isdigit()]
        word_tokens_english = [t for t in word_tokens_no_digits if t in english_words or not t.isalpha()]
        word_tokens_no_stops = [t for t in word_tokens_english if not t in english_stopwords]
        word_tokens_no_stops_lemmatized = [wordnet_lemmatizer.lemmatize(t) for t in word_tokens_no_stops]
        processed_corpus.append(word_tokens_no_stops_lemmatized)
    return processed_corpus

# %%
# %%time
df_train.comment_text = preprocess_text(df_train.comment_text)
df_test.comment_text = preprocess_text(df_test.comment_text)
# Out:
# CPU times: user 1min 47s, sys: 1.47 s, total: 1min 49s
# Wall time: 1min 54s

# %%
df_train[100:150]
# Out:
#                                                  comment_text  toxic  \
# id
# 1065542064              [3rd, party, cover, subject, v, r, P]      0
# 1086099304  [good, eve, I, agree, mostly, fine, afternoon,...      0
# 1098067176  [interesting, new, user, would, immense, knowl...      0
# 1099662066  [March, stop, continue, vandalize, blocked, ad...      0
# 1102537245  [spelling, Pluto, article, I, undid, article, ...      1
# 1108786298                                   [photo, request]      0
# 1115316430                   [userpage!, click, codelyoko193]      0
# 1130875035                   [refuse, explain, reason, block]      0
# 1137429102  [said, look, people, repost, material, true, a...      0
# 1148598836  [vandalism, edit, Adam, please, explain, going...      0
# 1150845666  [page, test, worked, removed, use, sandbox, wa...      0
# 1156286321  [nickname, As, I, The, first, one, television,...      0
# 1157220703     [I, also, like, point, thing, Korean, lexicon]      0
# 1164045443  [Carter, least, mid, importance, scale, top, d...      0
# 1174012385  [Paul, da, programmer, Wikipedia!, free, encyc...      0
# 1176678420  [The, linked, article, incorrect, figure, Euro...      0
# 1190311130  [I, need, point, obvious, personal, attack, Mr...      0
# 1198083804                               [evidence, provided]      0
# 1227668448          [game, nothing, Mexican, practice, squad]      0
# 1228414270                 [lede, take, look, abortion, lede]      0
# 1229646808  [little, touchy, also, seem, love, make, look,...      1
# 1243818932              [frequently, I, used, I, first, came]      0
# 1246453271  [time, suck, third, I, remember, I, say, Octob...      0
# 1267801288  [The, I, afraid, I, revert, edit, change, e, p...      0
# 1273021506                                         [A, GEEK!]      1
# 1306470083  [Marion, van, de, use, English, language, anyw...      0
# 1311827953               [stop, continue, vandalize, blocked]      0
# 1321814522  [I, got, new, job, time, constantly, monitor, ...      0
# 1357591601                      [got, well, maybe, must, nut]      0
# 1365464354  [song, I, watching, I, really, want, know, nam...      0
# 1365464552  [may, explicit, need, concentrated, India, cul...      0
# 1376817061                                                 []      0
# 1392815339                                           [School]      0
# 1397574294  [um, correct, English, composition, article, t...      0
# 1398901614                                             [I, I]      0
# 1403023535  [see, new, removal, Rab, noted, The, removal, ...      0
# 1446138065                                        [PRINTING!]      0
# 1454890762  [No, beta, release, The, creator, Sebastian, h...      0
# 1472348110  [I, tried, hide, delivery, day, seen, I, done,...      0
# 1475696849  [said, example, real, mostly, legit, site, art...      0
# 1479035868  [would, good, idea, familiarize, neutral, poin...      0
# 1506846893  [nice, someone, Dutch, could, appear, day, pub...      0
# 1510194680  [I, saw, Mr, thing, I, thought, making, refere...      0
# 1512511397  [missing, point, theory, Israel, converted, Ju...      0
# 1512938791  [every, enter, opposite, side, Jewish, coincid...      1
# 1542593818  [know, much, matter, now!, know, sea, change, ...      0
# 1553668749                [John, en, User_talk, Riff_Johnson]      0
# 1565719010  [Christmas, like, I, think, I, report, view, g...      0
# 1588358875  [trying, explain, I, advise, bother, unless, w...      0
# 1590833599  [For, last, time, Turkish, people, religiously...      1
#
#             severe_toxic  obscene  threat  insult  identity_hate
# id
# 1065542064             0        0       0       0              0
# 1086099304             0        0       0       0              0
# 1098067176             0        0       0       0              0
# 1099662066             0        0       0       0              0
# 1102537245             0        1       0       1              0
# 1108786298             0        0       0       0              0
# 1115316430             0        0       0       0              0
# 1130875035             0        0       0       0              0
# 1137429102             0        0       0       0              0
# 1148598836             0        0       0       0              0
# 1150845666             0        0       0       0              0
# 1156286321             0        0       0       0              0
# 1157220703             0        0       0       0              0
# 1164045443             0        0       0       0              0
# 1174012385             0        0       0       0              0
# 1176678420             0        0       0       0              0
# 1190311130             0        0       0       0              0
# 1198083804             0        0       0       0              0
# 1227668448             0        0       0       0              0
# 1228414270             0        0       0       0              0
# 1229646808             0        0       0       0              0
# 1243818932             0        0       0       0              0
# 1246453271             0        1       0       1              0
# 1267801288             0        0       0       0              0
# 1273021506             0        1       0       1              0
# 1306470083             0        0       0       0              0
# 1311827953             0        0       0       0              0
# 1321814522             0        0       0       0              0
# 1357591601             0        0       0       0              0
# 1365464354             0        0       0       0              0
# 1365464552             0        0       0       0              0
# 1376817061             0        0       0       0              0
# 1392815339             0        0       0       0              0
# 1397574294             0        0       0       0              0
# 1398901614             0        0       0       0              0
# 1403023535             0        0       0       0              0
# 1446138065             0        0       0       0              0
# 1454890762             0        0       0       0              0
# 1472348110             0        0       0       0              0
# 1475696849             0        0       0       0              0
# 1479035868             0        0       0       0              0
# 1506846893             0        0       0       0              0
# 1510194680             0        0       0       0              0
# 1512511397             0        0       0       0              0
# 1512938791             0        0       0       0              0
# 1542593818             0        0       0       0              0
# 1553668749             0        0       0       0              0
# 1565719010             0        0       0       0              0
# 1588358875             0        0       0       0              0
# 1590833599             0        0       0       0              0

# %% [markdown]
# ## Output

# %%
path = 'data/interim/train.csv'

dir_path = os.path.realpath('..')
full_path = os.path.join(dir_path, path)

df_train.to_csv(full_path, header=True, index=True)

# %%
path = 'data/interim/test.csv'

dir_path = os.path.realpath('..')
full_path = os.path.join(dir_path, path)

df_test.to_csv(full_path, header=True, index=True)
