# %%
import os
import numpy as np
import pandas as pd
import json

# %% [markdown]
# ## Import data

# %%
# load doc into memory
def load_doc(filename):
    # open the file as read only 
    file = open(filename, 'r')
    # read all text
    text = file.read()
    text = text.splitlines()
    # close the file file.close()
    return text

# %%
dir_path = os.path.realpath('..')

# %%
path = 'data/processed/train.csv'

full_path = os.path.join(dir_path, path)
df_train = pd.read_csv(full_path, header=0, index_col=0)
print("Dataset has {} rows, {} columns.".format(*df_train.shape))
# Out:
# Dataset has 95851 rows, 7 columns.

# %% [markdown]
# ## w2v training

# %%
from gensim.models import Word2Vec

# %%
import ast

# %%
sentences = [ast.literal_eval(y) for y in df_train.comment_text.tolist()]

# %%
# %%time
# train model
model = Word2Vec(sentences, min_count=0)
weights = model.wv.syn0
# Out:
# CPU times: user 34.8 s, sys: 229 ms, total: 35.1 s
# Wall time: 14.3 s

# %%
# summarize the loaded model
print(model)

# summarize vocabulary
words = list(model.wv.vocab)
# print(words)

# access vector for one word
print(model['sentence'])
# Out:
# Word2Vec(vocab=48349, size=100, alpha=0.025)
# ['tommy', 'v2', 'Conor', 'DISABLDABUSR!!!', 'tired', 'solo', 'diffusionism', '2C_continuing_copyvio', 'UNre4l', 'anuloma', 'SLC6A4', 'Gfoely4', 'audio', '23M', 'industrialism', 'drifting', 'denier', 'sham', 'consenting', 'bagel', 'corrupted', 'planet!', 'hour', 'F6', 'duff', 'decade', 'N1000', 'demonic', 'bib', 'dsa_cass', 'Glyph56', 'Jake', 'Node_ue', 'Manfred', 'pig!', 'predominately', 'scathing', '20mm', 'Rapido_', 'likeliness', 'jerk!', 'celebrate', 'updates!', 'demonstration', 'treasurer', 'Patricia', 'insane!', 'scuff', 'visiting!', 'harasser', 'Peace_be_upon_him_', 'moody', 'dolt!', 'Archive01', 'JACK!', 'electrolyte', 'silva', 'DR!', 'brooch', 'Keeper!', 'ave', 'Base64', 'famously', 'holic!', 'presuming', 'Stratfordian', 'proclaim', '0CC8Q6AEwATgo', 'apathy', 'tuned!', '592pix', 'otto', 'Phoenix', 'Albania!', 'backdrop', 'Giardia', 'Scandinavian', 'novelty', 'beast', 'parathyroid', 'standoffish', 'turkey12', 'nationwide', 'homeomorphic', 'ridging', 'say', 'conformist', 'twelve', 'carrying', 'University|term', 'oversimplification', 'cattiness', 'advance', 'fallaciously', 'geological', 'tanked', 'peerage', 'pie!', 'meditating', 'Klebsiella', 'tactile', 'Removal_of_text', 'Hillsborough_disaster', 'depose', 'fronx!!!', 'jane', 'Melia', 'stratification', 'oe', 'paa2009', 'fu_ck', 'flagship', 'Nazi', 'Gatoclass!', 'Mykungfu_Harassment', 'bitch!!!!!!!!!!', 'cityscape', 'danda', 'antipode', 'brei', 'unhealthily', 'shit!!!!!', 'Luddite', 'Alright!', 'office', 'fine', 'unfathomably', 'Miquonranger03', 'glossary', 'heartache', 'ENGLISH!', 'Confucian', 'holy!!', 'LaRouche_Movement', 'manuel_213942', 'Tiktaalik_by_Obsidian_Soul_modified', '|article', 'lanthanum', 'confirmed', 'comparable', 'leave!', 'itching', 'warren', 'developmental', 'incubate', 'TheWHAT!!', 'brains!', 'indulgent', 'conformity', 'nob', '25!', 'boa', 'Tab', 'veneer', 'wikipedia_quality_problem', 'PC1', 'photocopy', 'morbidity', 'afford', 'Monmouth', '|peerage', 'lad', 'scrub', 'jar', 'harlot', 'chop!', 'singularity', 'Paula!', 'unflinching', 'point!!!', 'Hiram', 'cares!', 'IGNORANTS!', '41f1972e', 'Paulist', 'Kaff!', 'demented', 'ambiguity', '2ndly', 'craw', 'relativity', 'meteorologic', 'school!', 'Fall_2015', 'diploma', 'on!!', '2!', '34MB', 'herne', 'Hawkeye', 'reminiscent', 'unsourced12', 'Sociologist4life', 'given!', '20rd', 'resinate', 'appointee', 'blonde!', '3oVSlNf0unI', 'bugged!', 'Rajasthani', 'PA62', 'WIKIPEDIA!', 'Should_we_remove_AT_Internet_Institute_from_web_client_stats', 'yen', 'Deepblue06', 'Archive_2', 'assert', 'angrily', 'Score_convergence', 'f5', 'precure', 'Alissahart!', 'terrace', 'ME!!!!', 'bobby', 'lubricant', 'V97', 'interface', 'barney', '|person', 'dt3', 'Tokyogirl97', 'spiritualism', 'aide', 'credit!', 'seine', 'dee', '72Dino', 'floss', 'duty', 'assent', 'flap!!!!!!!', 'digital', 'unorthodox', 'solar_wing', 'circulation', 'up!81', 'magically', 'charter', 'sniffle', 'pent', 'studiously', 'practiced', 'role', '4GB', 'alum', 'drenching', 'governmental', 'Special_operations_force', 'Chinese', 'Carolina', 'scrounge', 'reviving', 'tufting', 'dildo!', 'discouragement', 'tricorn', 'Freyja', 'stock', 'database!!', 'Canada!!!!', 'm4a', 'Kafka', '16GB', 'Joshuajohanson!', 'smugness', 'sewer', '6ZlcoUiSsf', 'wanker!', 'ectoderm', 'cation', 'auction', 'patriot', 'Sinclair_ZX81', 'Green205', 'Resurrection||1997||', 'stop', 'renominate', 'mania', 'Denmark', '20Klum', 'V86', 'painfully!', 'LOST!', 'Stradivarius', '5C06', 'coherent', 'fishery', 'Honey!', 'id15', 'VANDAL!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!', 'F4', 'retina', '160x160', 'behest', 'weeks!', 'communicativeness', 'destructive', 'Finder2', 'lolz!', 'mobocracy', 'Davejohnsan!', 'yewww!go', 'immersive', 'impersonal', 'wir', '0wn', 'reach', 'WOULD!', 'manzanita', 'creature!!', 'morbid', 'leap', 'bumpkin', 'chartered', 'blockade', 'vaginal', 'SPONGEBOB!!!!!!', 'indentation', 'riot!!', 'proportionate', 'railing', 'no!!', 'influx', 'neon', 'history!!!!!', 'here!!Platanogenius', 'Cyclopes', 'pushpin',  ...
# [ 3.22518682  0.3189618   0.63442034  0.25301379  0.11301434  0.47010943
#  -0.2976068   0.04045914 -0.97768086 -0.16618843 -0.31420007  2.00468636
#  -1.1161859   0.58009553 -0.32770142  1.03972113  0.10722311 -0.19695342
#  -1.29115069  0.35215831 -0.33603495  1.06827629  1.37652194  0.12951924
#   0.22117105  0.10744268 -0.94186819  0.64119095 -2.10430431 -3.37200522
#  -0.27199712 -1.86220145  0.79803836 -0.87763637  0.67189288 -2.07859063
#  -2.14920902 -0.18509938 -0.97752738 -0.88605762  0.40049782 -0.71838218
#   1.00517106 -0.26511851  0.44006404 -1.72360718  0.22415279 -2.09020758
#  -0.22300357  0.4981629  -0.17025855 -0.49432582 -0.21524771  0.21108896
#   0.78438169  1.04930604  0.08447487 -1.17147899 -1.79206622  0.34441635
#   0.54727232 -0.33979425  2.31927276  0.32469428  0.68240899  0.40189108
#   0.11648943  0.65929556  1.6227144  -1.32397723 -0.76961929 -1.28073561
#   0.02089396 -1.8494004   0.26569039 -0.3132534   0.97726345  1.12819767
#  -0.51461142 -0.82974893 -0.08293243  0.75719881  1.61229169  0.39902112
#   0.64023566 -1.5249424  -2.50320029 -0.37682202 -0.21083289 -1.05452967
#   0.18749577  2.22455359  1.10955727  1.02796221 -0.87660706  0.22096443
#   0.07810071  1.39308798 -0.87197191 -1.36638474]

# %% [markdown]
# ## Save model

# %%
# save model
model.save('w2v_model.bin')

# %%
# save embedding weights
embeddings_path = 'embeddings.npy'
np.save(open(embeddings_path, 'wb'), weights)

# %%
# save w2v vocab
vocab_path = 'vocab.json'
vocab = dict([(k, v.index) for k, v in model.wv.vocab.items()])
with open(vocab_path, 'w') as f:
    f.write(json.dumps(vocab))

# %%
model.wv.get_keras_embedding()
# Out:
# Using TensorFlow backend.
