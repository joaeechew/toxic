# %%
CREATE NONE
CHECK CORRELATIONS BETWEEN CAPS and otehr features

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
dir_path = os.path.realpath('..')

# %%
path = 'data/raw/train.csv'

full_path = os.path.join(dir_path, path)
df = pd.read_csv(full_path, header=0, index_col=0)
print("Dataset has {} rows, {} columns.".format(*df.shape))
# Out:
# Dataset has 95851 rows, 7 columns.

# %%
labels = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
df['none'] = 1-df[labels].max(axis=1)
df['total'] = df[labels].sum(axis=1)

# %%
df.head()
# Out:
#                                                comment_text  toxic  \
# id
# 22256635  Nonsense?  kiss off, geek. what I said is true...      1
# 27450690  "\n\n Please do not vandalize pages, as you di...      0
# 54037174  "\n\n ""Points of interest"" \n\nI removed the...      0
# 77493077  Asking some his nationality is a Racial offenc...      0
# 79357270  The reader here is not going by my say so for ...      0
#
#           severe_toxic  obscene  threat  insult  identity_hate  none  \
# id
# 22256635             0        0       0       0              0     0
# 27450690             0        0       0       0              0     1
# 54037174             0        0       0       0              0     1
# 77493077             0        0       0       0              0     1
# 79357270             0        0       0       0              0     1
#
#           uppercase_count  total
# id
# 22256635             1033      1
# 27450690             1033      0
# 54037174             1033      0
# 77493077             1033      0
# 79357270             1033      0

# %%
df.describe()
# Out:
#               toxic  severe_toxic       obscene        threat        insult  \
# count  95851.000000  95851.000000  95851.000000  95851.000000  95851.000000
# mean       0.096368      0.010068      0.053301      0.003182      0.049713
# std        0.295097      0.099832      0.224635      0.056320      0.217352
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        identity_hate          none  uppercase_count         total
# count   95851.000000  95851.000000          95851.0  95851.000000
# mean        0.008492      0.897862           1033.0      0.221124
# std         0.091762      0.302831              0.0      0.750533
# min         0.000000      0.000000           1033.0      0.000000
# 25%         0.000000      1.000000           1033.0      0.000000
# 50%         0.000000      1.000000           1033.0      0.000000
# 75%         0.000000      1.000000           1033.0      0.000000
# max         1.000000      1.000000           1033.0      6.000000

# %%
target = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate', 'none']

# %%
# Calculate means
mean = df[target].mean().sort_values(ascending=False)
 
# Barplot
sns.barplot(x=mean.index, y=mean.values)
print(mean)
# Out:
# none             0.897862
# toxic            0.096368
# obscene          0.053301
# insult           0.049713
# severe_toxic     0.010068
# identity_hate    0.008492
# threat           0.003182
# dtype: float64

# %%
# Calculate correlations
corr = df[target].corr()
 
# Heatmap
sns.heatmap(corr, annot=True, fmt='.2f')

# %%
df.head()
# Out:
#                                                comment_text  toxic  \
# id
# 22256635  Nonsense?  kiss off, geek. what I said is true...      1
# 27450690  "\n\n Please do not vandalize pages, as you di...      0
# 54037174  "\n\n ""Points of interest"" \n\nI removed the...      0
# 77493077  Asking some his nationality is a Racial offenc...      0
# 79357270  The reader here is not going by my say so for ...      0
#
#           severe_toxic  obscene  threat  insult  identity_hate  none  \
# id
# 22256635             0        0       0       0              0     0
# 27450690             0        0       0       0              0     1
# 54037174             0        0       0       0              0     1
# 77493077             0        0       0       0              0     1
# 79357270             0        0       0       0              0     1
#
#           uppercase_count
# id
# 22256635             1033
# 27450690             1033
# 54037174             1033
# 77493077             1033
# 79357270             1033

# %%
print(df[df['total'] == 1])
# Out:
#                                                    comment_text  toxic  \
# id
# 22256635      Nonsense?  kiss off, geek. what I said is true...      1
# 225701312     Why hasn't Alitalia been removed rom the allia...      1
# 293668009     "\nThe Graceful Slick....\nIs non other than a...      1
# 341549388     "\n\n Stupid? \n\nAs soon as I saw the phrase ...      1
# 407636870                           Are you gay?? Sound like it      1
# 659300233     and in the program on last night Crime Museum:...      1
# 839277218     "\n\nI didn't call you a ""biased backward yan...      1
# 955104481     HE THINKS THEY ARE COPYRIGHT VIOLATION. PITY H...      1
# 1229646808    "\n\nWow, you're a little touchy aren't you? Y...      1
# 1512938791    COINCIDENCE? \n\nHave you noticed that in ever...      1
# 1590833599    For the last time, Turkish people ARE NOT WHIT...      1
# 2302694137            u aint got no pancake mix lady so stopppp      1
# 2445585834    "\n\n I TAKE OFFENSE! \n\nI take great offense...      1
# 2957906887    YOU!\nYou blocked me worm why!!!!!!!!!!!!!!!!!...      1
# 3118614908    "\n\n  BREAKING NEWS!!!! I KNOW THIS IS ONLY F...      1
# 3275828380    Another stupid person who considers leaving a ...      0
# 3733982411    Why do you like to smear fecal matter all over...      1
# 3844716110    He was right. You are all a bunch of bullies. ...      1
# 4111217019    "\nYou shoot your entire imbecilic argument in...      1
# 5001526614                shut the hell up \n\nZabrak\nDragong4      1
# 5905749491    You can take your sandbox\n\nAnd pull your che...      1
# 6592369368    "\n\n haiti \nhey, can you explain what the wi...      1
# 6782934424    "\n\nAnd I don't usually talk to morons. But h...      1
# 7542550676        Ram it up ur ass very hard till ur eyes water      0
# 7548054308    I,m the bane of your existence!!! \n\nHey Gaas...      1
# 7716901916    "\n\n thanks for my suspention \n\nhi HERE to ...      1
# 8043164441    "==hunk==\n\nYOU'VE BEEN HIT BY THE\n\n|^^^^^^...      1
# 8186703849    P.S- How the hell are you going to block me wh...      1
# 8334044385    Just when you thought they couldn't possibly g...      0
# 8397497553          touch little boys' private parts. It's fun.      1
# ...                                                         ...    ...
# 992079325462  spent the worst 3 months of my life in this he...      1
# 992395236028  THE RETURN \nhello, Fan-1967. you may not reme...      1
# 992923707568  Your comments on WP:AN/I \n\nTomer, while I ca...      1
# 992954943606  "\nMaybe I should have been clearer - there ar...      1
# 993095062898        I am wrecking your Wikipedia. Do something.      1
# 993198421047  QUIT EDITING CHICAGO MED \n\nYOU ARE SO STUPID...      1
# 993331217149  Deleting my question, or banning me, doesn't m...      1
# 993582624102  Mistakes\n\nSince you idiots won't let me edit...      1
# 993785542703  HELLO NAWLINS \n\nWhy do you like to deflower ...      1
# 993846829404  David Duke\n\nWhy did you remove truth from th...      1
# 994075897782  I know that there is an unfortunate coincidenc...      1
# 994290103914  Yes they were Hitler Stated that Slavs were le...      1
# 994732217963  NEVER warn me again.  You are wrong about it. ...      1
# 995188967325  The above user, who has failed to sign, is ign...      0
# 996347842192  Already left it on the other page \n\nSO EITHE...      1
# 996537837731                       Wikipedia is a Comunist Plot      1
# 996686877645                @ okay king of the Wikipedia Nazis.      1
# 996983111922  WE ARE JUST TRYING TO PROTEST THE MILITARY GOV...      1
# 997164476596  Hard to be constructive when the other party b...      1
# 997191080405                              are you a commie tho?      1
# 997556841164  "\nShut the heck up; they were not reversals. ...      1
# 998243713423  7>STOP EDITING MY POSTS DIPSHIT \nI HAVE A RIG...      1
# 998417631015        MATTYTHEWHITE IS A SADCASE PLEASE GO TO BED      1
# 998848254815  Who are you? \n\nI must admit, you are not the...      1
# 999108831459  Only a sad loser janitor would think that bein...      1
# 999120801929  , and to suggest that is flabbergastingly arro...      1
# 999307596544  "\n\n Wikipedia is a bias organization. I prov...      1
# 999568811424  2007 (UTC)\n\nYour continued rudeness and fail...      1
# 999583301967  "\nThen block me then BK.  I remember revertin...      1
# 999663934395  cheshire \n\nget a life dude, like this is a r...      1
#
#               severe_toxic  obscene  threat  insult  identity_hate  none  \
# id
# 22256635                 0        0       0       0              0     0
# 225701312                0        0       0       0              0     0
# 293668009                0        0       0       0              0     0
# 341549388                0        0       0       0              0     0
# 407636870                0        0       0       0              0     0
# 659300233                0        0       0       0              0     0
# 839277218                0        0       0       0              0     0
# 955104481                0        0       0       0              0     0
# 1229646808               0        0       0       0              0     0
# 1512938791               0        0       0       0              0     0
# 1590833599               0        0       0       0              0     0
# 2302694137               0        0       0       0              0     0
# 2445585834               0        0       0       0              0     0
# 2957906887               0        0       0       0              0     0
# 3118614908               0        0       0       0              0     0
# 3275828380               0        0       0       1              0     0
# 3733982411               0        0       0       0              0     0
# 3844716110               0        0       0       0              0     0
# 4111217019               0        0       0       0              0     0
# 5001526614               0        0       0       0              0     0
# 5905749491               0        0       0       0              0     0
# 6592369368               0        0       0       0              0     0
# 6782934424               0        0       0       0              0     0
# 7542550676               0        1       0       0              0     0
# 7548054308               0        0       0       0              0     0
# 7716901916               0        0       0       0              0     0
# 8043164441               0        0       0       0              0     0
# 8186703849               0        0       0       0              0     0
# 8334044385               0        0       0       1              0     0
# 8397497553               0        0       0       0              0     0
# ...                    ...      ...     ...     ...            ...   ...
# 992079325462             0        0       0       0              0     0
# 992395236028             0        0       0       0              0     0
# 992923707568             0        0       0       0              0     0
# 992954943606             0        0       0       0              0     0
# 993095062898             0        0       0       0              0     0
# 993198421047             0        0       0       0              0     0
# 993331217149             0        0       0       0              0     0
# 993582624102             0        0       0       0              0     0
# 993785542703             0        0       0       0              0     0
# 993846829404             0        0       0       0              0     0
# 994075897782             0        0       0       0              0     0
# 994290103914             0        0       0       0              0     0
# 994732217963             0        0       0       0              0     0
# 995188967325             0        0       0       1              0     0
# 996347842192             0        0       0       0              0     0
# 996537837731             0        0       0       0              0     0
# 996686877645             0        0       0       0              0     0
# 996983111922             0        0       0       0              0     0
# 997164476596             0        0       0       0              0     0
# 997191080405             0        0       0       0              0     0
# 997556841164             0        0       0       0              0     0
# 998243713423             0        0       0       0              0     0
# 998417631015             0        0       0       0              0     0
# 998848254815             0        0       0       0              0     0
# 999108831459             0        0       0       0              0     0
# 999120801929             0        0       0       0              0     0
# 999307596544             0        0       0       0              0     0
# 999568811424             0        0       0       0              0     0
# 999583301967             0        0       0       0              0     0
# 999663934395             0        0       0       0              0     0
#
#               uppercase_count  total
# id
# 22256635                 1033      1
# 225701312                1033      1
# 293668009                1033      1
# 341549388                1033      1
# 407636870                1033      1
# 659300233                1033      1
# 839277218                1033      1
# 955104481                1033      1
# 1229646808               1033      1
# 1512938791               1033      1
# 1590833599               1033      1
# 2302694137               1033      1
# 2445585834               1033      1
# 2957906887               1033      1
# 3118614908               1033      1
# 3275828380               1033      1
# 3733982411               1033      1
# 3844716110               1033      1
# 4111217019               1033      1
# 5001526614               1033      1
# 5905749491               1033      1
# 6592369368               1033      1
# 6782934424               1033      1
# 7542550676               1033      1
# 7548054308               1033      1
# 7716901916               1033      1
# 8043164441               1033      1
# 8186703849               1033      1
# 8334044385               1033      1
# 8397497553               1033      1
# ...                       ...    ...
# 992079325462             1033      1
# 992395236028             1033      1
# 992923707568             1033      1
# 992954943606             1033      1
# 993095062898             1033      1
# 993198421047             1033      1
# 993331217149             1033      1
# 993582624102             1033      1
# 993785542703             1033      1
# 993846829404             1033      1
# 994075897782             1033      1
# 994290103914             1033      1
# 994732217963             1033      1
# 995188967325             1033      1
# 996347842192             1033      1
# 996537837731             1033      1
# 996686877645             1033      1
# 996983111922             1033      1
# 997164476596             1033      1
# 997191080405             1033      1
# 997556841164             1033      1
# 998243713423             1033      1
# 998417631015             1033      1
# 998848254815             1033      1
# 999108831459             1033      1
# 999120801929             1033      1
# 999307596544             1033      1
# 999568811424             1033      1
# 999583301967             1033      1
# 999663934395             1033      1
#
# [3833 rows x 10 columns]

# %%
df['processed'] = df['comment_text'].str.split()

# %%
from collections import Counter
df['uppercase_count'] = df['processed'].apply(lambda x: sum(1 for t in x if t.isupper() and len(t)>2))

# %%
sns.regplot(x="toxic", y="uppercase_count", data=df, x_jitter=0.1)

# %%
features = df.drop(['none', 'total', 'processed'], axis=1)

# %%
features.head()
# Out:
#                                                comment_text  toxic  \
# id
# 22256635  Nonsense?  kiss off, geek. what I said is true...      1
# 27450690  "\n\n Please do not vandalize pages, as you di...      0
# 54037174  "\n\n ""Points of interest"" \n\nI removed the...      0
# 77493077  Asking some his nationality is a Racial offenc...      0
# 79357270  The reader here is not going by my say so for ...      0
#
#           severe_toxic  obscene  threat  insult  identity_hate  \
# id
# 22256635             0        0       0       0              0
# 27450690             0        0       0       0              0
# 54037174             0        0       0       0              0
# 77493077             0        0       0       0              0
# 79357270             0        0       0       0              0
#
#           uppercase_count
# id
# 22256635                0
# 27450690                0
# 54037174                0
# 77493077                0
# 79357270                0

# %%
path = 'data/processed/features.csv'
full_path = os.path.join(dir_path, path)
features.to_csv(full_path, header=True, index=True)
